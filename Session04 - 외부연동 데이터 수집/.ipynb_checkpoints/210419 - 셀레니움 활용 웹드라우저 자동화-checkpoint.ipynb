# %% [markdown]
# ## 셀레니움 활용 웹브라우져 자동화
# ##### 셀리니움 통해 로그인도 가능.

# %% [markdown]
# ##### 셀리니움 환경 구축방법, 셀리니움 활용 웹 브라우저 자동화방법 익히기

# %% [markdown]
# ###### ---- pip install selenium

# %% [markdown]
# ##### 1. 크롬 브라우져 버전확인

# %% [markdown]
# ##### 2. 버전에 맞게 크롬 드라이버 설치

# %% [markdown]
# ### 1. 라이브러리 선언

# %%
from selenium import webdriver

import pandas as pd

# %% [markdown]
# ### 2. 웹브라우저 설정

# %%
options = webdriver.ChromeOptions()

# 헤드리스 옵션 / 일반 옵션
# 일반 - 브라우저를 진짜 띄운다.
# 헤드리스 - 브라우저를 띄우지 않고 크롤링.

options.add_argument("window-size=1920*1080") #pypi.org 들가면 나와있따.

driverLoc = "../addon/chromedriver/chromedriver.exe"

driver = webdriver.Chrome(executable_path=driverLoc, options=options) # 파라미터를 지정(변수로 지정해주면) 했으면 둘다 변수로 지정해줘야한다.

# %%
# 헤드리스 설정 시 리눅스같이 웹화면 없는 경우에도 웹페이지 실행 가능함# \
## options.add_argument('headless’)# options.add_argument("disable-gpu")

# %%
### 웹페이지 파싱 될때까지 최대 3초 기다림
driver.implicitly_wait(3)

# %% [markdown]
# ### 3. 브라우저 열기

# %%
targetUrl = "https://www.sparkkorea.com"

# %%
## get 함수를 써서 url정보를 던져주면 이동.
driver.get(targetUrl)

# %%
## timesleep 주기
## 1초 대기
import time
time.sleep(1)

# %%
## 페이지 소스에 접근 가능
driver.page_source
# Out:
# '<html lang="ko-KR"><head>\n<meta charset="UTF-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<link rel="profile" href="http://gmpg.org/xfn/11">\n<link rel="pingback" href="https://sparkkorea.com/xmlrpc.php">\n\n<title>스파크 코리아 – 스파크코리아 자료공유</title>\n<meta name="robots" content="max-image-preview:large">\n<meta name="google-site-verification" content="QRZVgHsoL23RuwmgmXNuXfO-mUaxCkdvhP2rRvLT270">\n\n<!-- Async WordPress.com Remote Login -->\n\n<link rel="dns-prefetch" href="//s0.wp.com">\n<link rel="dns-prefetch" href="//sparkkorea.wordpress.com">\n<link rel="dns-prefetch" href="//wordpress.com">\n<link rel="dns-prefetch" href="//fonts.googleapis.com">\n<link rel="alternate" type="application/rss+xml" title="스파크 코리아 » 피드" href="https://sparkkorea.com/feed/">\n<link rel="alternate" type="application/rss+xml" title="스파크 코리아 » 댓글 피드" href="https://sparkkorea.com/comments/feed/">\n\t<script type="text/javascript">\n\t\t/* <![CDATA[ */\n\t\tfunction addLoadEvent
# ...

# %% [markdown]
# ### 4. 브라우저 내 액션(클릭)

# %% [markdown]
# #### 웹 개발자도구에서 크롤링 원하는 영역 copyXPath

# %%
quizBtnXpath = '//*[@id="menu-item-382"]/a'    ## 문자 안에 쌍따음표 있으니 홑따음표로 감싸주기.

# %%
quizBtn = driver.find_element_by_xpath(quizBtnXpath)

# %%
quizBtn.click() ## 클릭이 된다. 겁나신기하네

# %% [markdown]
# ### 4.1 브라우저 내 액션(텍스트 입력)

# %% [markdown]
# #### 텍스트 입력 라이브러리

# %%
from selenium.webdriver.common.keys import Keys

# %%
## Keys 라이브러리를 통해 원하는 버튼을 누를 수 있다.

# %%
Keys.

# %%
googleUrl = "https://www.google.com"

# %%
driver.get(googleUrl)

# %%
## 검색창 위에서 우클릭. 검사
## /html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input

# %%
googleSearchXpath = "/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input"

# %%
googleSearchBox =  driver.find_element_by_xpath(googleSearchXpath)

# %%
googleSearchBox
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5488eefaaf3b663547a489793ae15d02", element="75017646-f79c-4da1-9ce0-665722b9a6b4")>

# %%
searchKeyword = "스마트금융과"

# %%
## 스마트금융과 검색
googleSearchBox.send_keys(searchKeyword)

# %%
## 스마트금융과 입력 후 엔터를 눌러서 검색시켰다.
googleSearchBox.send_keys(Keys.ENTER)

# %% [markdown]
# ### 5. 페이지 URL 및 소스 가져오기

# %%
finalUrl = driver.current_url

# %%
finalUrl
# Out:
# 'https://www.google.com/search?q=%EC%8A%A4%EB%A7%88%ED%8A%B8%EA%B8%88%EC%9C%B5%EA%B3%BC&source=hp&ei=kh99YLvuNaXpmAXamqeIBQ&iflsig=AINFCbYAAAAAYH0togr2o1d9iJMjWsLXose2WvGeyL_4&oq=%EC%8A%A4%EB%A7%88%ED%8A%B8%EA%B8%88%EC%9C%B5%EA%B3%BC&gs_lcp=Cgdnd3Mtd2l6EAMyAggAUKf9D1jA_Q9grdQRaAJwAHgDgAGFAYgB2gOSAQMxLjOYAQCgAQGqAQdnd3Mtd2l6sAEA&sclient=gws-wiz&ved=0ahUKEwi7_5vY04nwAhWlNKYKHVrNCVEQ4dUDCAc&uact=5'

# %%
pgSource = driver.page_source

# %%
pgSource
# Out:
# '<html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="ko"><head><meta charset="UTF-8"><meta content="origin" name="referrer"><meta content="Anb2GUnhMjfTIX0D2a4a6NPAqPI5GaxxRAiF81XTjHJ2qK4E3Hw3VFM4eaJBgRzz45CNPt624audv+wHOJwfAAEAAABieyJvcmlnaW4iOiJodHRwczovL2dvb2dsZS5jb206NDQzIiwiZmVhdHVyZSI6IlRydXN0VG9rZW5zIiwiZXhwaXJ5IjoxNjI2MjIwNzk5LCJpc1N1YmRvbWFpbiI6dHJ1ZX0=" http-equiv="origin-trial"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>스마트금융과 - Google 검색</title><script src="https://apis.google.com/_/scs/abc-static/_/js/k=gapi.gapi.en.jcYff4gdSOQ.O/m=gapi_iframes,googleapis_client/rt=j/sv=1/d=1/ed=1/rs=AHpOoo_CvAHQybwQAZJQL2tdeysMj0HgHw/cb=gapi.loaded_0" nonce="P3kijFanNo69Xxw/sv5QDw==" async=""></script><script nonce="P3kijFanNo69Xxw/sv5QDw==">(function(){window.google={kEI:\'tCB9YOnAH5rrwQOBsoqoCA\',kEXPI:\'31\',kBL:\'f_Ps\'};google.sn=\'web\';google.kHL=\'ko\';})();(function(){\nvar f,h=[];function k(a){for(var
# ...

# %% [markdown]
# ### 6. 여기까지가 셀레니움의 역활. 그다음에는 bs4 이용.

# %%
import bs4

bsObj = bs4.BeautifulSoup(pgSource, "html.parser")

bsObj.find("a")

# %%
## 신기하당

# %%
### copy selector 는 id, class 정보를 가져온다.
#menu-item-382 > a

# %% [markdown]
# ### # -> id     . -> class

# %%
driver.get(targetUrl)

# %%
quizElementId = "menu-item-382" ## a를 빼자.

# %%
## 반응형 웹에는 퀴즈 버튼이 생겻다 말았다 한다. 주의하자.
driver.find_element_by_id(quizElementId).click()

# %% [markdown]
# ### 메일전송 자동화

# %%
mport getpass

pw = getpass.getpass()  # 안보이게 암호화 -> 컴퓨터용 앱비밀번호 적어넣기

import pickle  # 패쓰워드 암호화
mypass = zmjrhohanhnbrtfv # ->(컴퓨터용 앱비밀번호)

# save
with open('pw.pickle', 'wb') as f:
    pickle.dump(pw, f, pickle.HIGHEST_PROTOCOL)

# load
with open('pw.pickle', 'rb') as f:
    pw = pickle.load(f)

# %%
import pickle

mypass = "eswblpxekeqqtxqe"

# 데이터를 저장
with open('pw.pickle', 'wb') as handle: 
    pickle.dump(pw, handle, protocol=pickle.HIGHEST_PROTOCOL)

# load
with open('pw.pickle', 'rb') as f:
    pwpickle = pickle.load(handle)

smtp_hmail.login(userid, pwpickle)

# %%
import smtplib

from email.message import EmailMessage

smtp_gmail = smtplib.SMTP('smtp.gmail.com', 587)
# 서버 연결을 설정하는 단계
smtp_gmail.ehlo()
# 연결을 암호화
smtp_gmail.starttls()
#로그인
userid = "km1031kim@gmail.com"
userpw = "eswblpxekeqqtxqe"
smtp_gmail.login(userid, userpw)
# Out:
# (235, b'2.7.0 Accepted')

# %%
# csv파일로 이메일 값을 가져와서 to 에 넣어도 된다.

# %%
import pandas as pd

# %%
emailData
# Out:
#                 name.email
# 김진규    km1031kim@naver.com
# 진규킴  km1031kim@hanmail.net

# %%
# 수신자 확인
to = [emailData[0][1], emailData[1][1]]

msg=EmailMessage()

# 제목 입력
msg['Subject']="줠라신기하네~"

# 내용 입력
msg.set_content("졸라신기하네")

# 보내는 사람
msg['From']='km1031kim@gmail.com'

# 받는 사람
msg['To'] = ",".join(to)

file2='quiz_result.csv' # 현재 위치에 있는 quiz파일을
fp = open(file2,'rb') # 오픈해서 file data에 집어넣고
file_data=fp.read()
msg.add_attachment(file_data, ##m sg에 첨부파일 추가, 밑엔 메타정보 속성들
maintype='text',
subtype='plain',
filename=file2) # file2라는 이름으로 보낸다.

# 메일 전송
smtp_gmail.send_message(msg)
smtp_gmail.close()

# %%
첨부파일 #1 추가
file='0318_오후2.png'
fp = open(file,'rb')
file_data=fp.read()
msg.add_attachment(file_data,
maintype='text',
subtype='plain',
filename=file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-bbc7f33125f4> in <module>
# ----> 1 첨부파일 #1 추가
#       2 file='0318_오후2.png'
#       3 fp = open(file,'rb')
#       4 file_data=fp.read()
#       5 msg.add_attachment(file_data,
#
# NameError: name '첨부파일' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# SMTPServerDisconnected                    Traceback (most recent call last)
# <ipython-input-27-cacbbb6cb28f> in <module>
#       7 filename=file2) # file2라는 이름으로 보낸다.
#       8 # 메일 전송
# ----> 9 smtp_gmail.send_message(msg)
#      10 smtp_gmail.close()
#
# ~\anaconda3\lib\smtplib.py in send_message(self, msg, from_addr, to_addrs, mail_options, rcpt_options)
#     968             g.flatten(msg_copy, linesep='\r\n')
#     969             flatmsg = bytesmsg.getvalue()
# --> 970         return self.sendmail(from_addr, to_addrs, flatmsg, mail_options,
#     971                              rcpt_options)
#     972
#
# ~\anaconda3\lib\smtplib.py in sendmail(self, from_addr, to_addrs, msg, mail_options, rcpt_options)
#     863             for option in mail_options:
#     864                 esmtp_opts.append(option)
# --> 865         (code, resp) = self.mail(from_addr, esmtp_opts)
# ...
