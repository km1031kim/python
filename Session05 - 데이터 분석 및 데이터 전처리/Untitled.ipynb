# %%
import pandas as pd

# %%
joindata1 = pd.read_csv("../dataset/joindata1.csv")

# %%
joindata1
# Out:
#        mata_tin  mata_txpr_sex_cd mate_mdf_yn mate_srcs_cntn  mem_rit_cd  \
# 0  153601000000                 3           Y        대법원가족관계           2
# 1  154102000000                 3           Y        대법원가족관계           1
# 2  153500000000                 3           Y        대법원가족관계           2
# 3  155000000000                 3           Y        대법원가족관계           2
# 4  153500000000                 3           Y        대법원가족관계           2
# 5  100026000000                 3           Y        대법원가족관계           1
# 6  153500000000                 3           Y        대법원가족관계           2
# 7  153500000000                 3           Y        대법원가족관계           2
# 8  153500000000                 3           Y        대법원가족관계           2
# 9  153500000000                 3           Y        대법원가족관계           2
#
#    rit_end_dt  rit_strt_dt      suta_tin  suta_txpr_sex_cd
# 0    99991231     20190107  153403000000                 2
# ...

# %%
joindata2 = pd.read_csv("../dataset/joindata2.csv",  encoding='cp949')

# %%
joindata2
# Out:
#        mata_tin mate_srcs_cntn  rit_end_dt  rit_strt_dt      suta_tin  \
# 0  153101000000          납세자관계    99991231        10101  153403000000
# 1  153101000000          납세자관계    99991231        10101  154201000000
# 2  153101000000          납세자관계    99991231        10101  154601000000
# 3  153101000000          납세자관계    99991231        10101  154702000000
# 4  153101000000          납세자관계    99991231        10101  153403000000
# 5  153101000000          납세자관계    20161113     20160523  153201000000
# 6  153101000000          납세자관계    99991231        10101  153501000000
# 7  153101000000          납세자관계    99991231        10101  153101000000
# 8  153101000000          납세자관계    99991231        10101  153901000000
# 9  153101000000          납세자관계    20180926     20170802  154401000000
#
#    txpr_rlt_cd
# 0           22
# 1           22
# 2           30
# 3           22
# 4           32
# 5           30
# 6           22
# 7           32
# 8           32
# 9           30

# %%
mergedData = pd.merge(left=joindata1,
         right=joindata2,
         on="suta_tin",
         how="inner")

# %% [markdown]
# ## suta_tin 이 같은것만 뽑자

# %%
mergedData
# Out:
#      mata_tin_x  mata_txpr_sex_cd mate_mdf_yn mate_srcs_cntn_x  mem_rit_cd  \
# 0  153601000000                 3           Y          대법원가족관계           2
# 1  153601000000                 3           Y          대법원가족관계           2
#
#    rit_end_dt_x  rit_strt_dt_x      suta_tin  suta_txpr_sex_cd    mata_tin_y  \
# 0      99991231       20190107  153403000000                 2  153101000000
# 1      99991231       20190107  153403000000                 2  153101000000
#
#   mate_srcs_cntn_y  rit_end_dt_y  rit_strt_dt_y  txpr_rlt_cd
# 0            납세자관계      99991231          10101           22
# 1            납세자관계      99991231          10101           32

# %%
mergedData["new_suta_in"] = mergedData.suta_tin

# %%
mergedData.rename(columns = {'mata_tin_x' : 'mata_tin'}, inplace = True)

# %%
finalData = pd.merge(left=joindata1,
         right=mergedData,
         on="mata_tin",
         how="left")

# %%
finalData
# Out:
#         mata_tin  mata_txpr_sex_cd_x mate_mdf_yn_x mate_srcs_cntn  \
# 0   153601000000                   3             Y        대법원가족관계
# 1   153601000000                   3             Y        대법원가족관계
# 2   154102000000                   3             Y        대법원가족관계
# 3   153500000000                   3             Y        대법원가족관계
# 4   155000000000                   3             Y        대법원가족관계
# 5   153500000000                   3             Y        대법원가족관계
# 6   100026000000                   3             Y        대법원가족관계
# 7   153500000000                   3             Y        대법원가족관계
# 8   153500000000                   3             Y        대법원가족관계
# 9   153500000000                   3             Y        대법원가족관계
# 10  153500000000                   3             Y        대법원가족관계
#
#     mem_rit_cd_x  rit_end_dt  rit_strt_dt    suta_tin_x  suta_txpr_sex_cd_x  \
# 0              2    99991231     20190107  153403000000                   2
# ...
