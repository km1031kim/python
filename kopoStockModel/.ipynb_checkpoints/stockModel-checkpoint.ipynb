# %% [markdown]
# ##### 불린저 밴드??
# ###### 주가는 등락을 거듭하지만 통계적으로 보면, 중심선인 이동평균선을 따라 일정한 밴드 범위 안에서 움직인다.
# ###### 이와 같이 이동평균선을 중심으로 표준편차 범위 내에서 주가가 움직인다는 것을 전제로 하여, 위쪽에 상한 밴드, 아래쪽에 하한 밴드를 만들면 변동폭의 띠가 형성되는데 이를 Bollinger Band라고 한다.

# %% [markdown]
# #### 이동평균선 따라 매매하자. 이동평균선을 보면 주가의 방향성과 변곡점을 쉽게 알 수 있어 마음편한 매매가 가능하다.

# %% [markdown]
# ### 주가의 진행방향을 나타내므로 미래의 주가 동향을 예측할 수 있게 해준다..

# %% [markdown]
# #### 최근일부터 계산, 가장 먼 날짜를 빼고 최근일을 포함하는 선입선출 방식으로 단순평균을 낸다

# %% [markdown]
# ### 활용방법
# ##### 1. 상승추세 : 이동평균선이 상승.. 주가가 5일 이동평균선 위에 있는 경우. 상승세 지속
#
# ##### 2. 하락추세 : 이동평균선이 하락.. 주가가 5일 이동평균선 아래에 있는 경우.
#
# ##### 3. 횡보추세 : 이동평균선이 횡보하는 동안에는 주가가 횡보..

# %% [markdown]
# ### 위를 바탕으로 매수, 매도 시점을 파악한다

# %% [markdown]
# ##### 1. 상승 전환 : 하락하던 주가가 5일 이동평균선을 상향 돌파하면 매수시점으로 본다. 주가가 5일, 20일 이동평균선을 차례로 돌파, 5일 이동평균선도 상승으로 돌아서면 적극 매수

# %% [markdown]
# ##### 2. 하락 전환 : 상승하던 주가가 5일 이동평균선을 하락 돌파하면 매도시점. 주가가 5일선, 20일선을 차례로 돌파하고 5일이동평균선도 하락으로 전환되면 적극 매도.

# %% [markdown]
# ##### 3. 횡보 : 이동평균선이 횡보하는 상태에서 주가가 이동평균선 위로 상승하면 매수, 하락하면 매매.
# ##### 특히 주가가 장기 하락하여 주가와 이동평균선이 수렴한 곳에서 주가가 5일선 또는 20일선 등 중단기 이동평균성르 동시에 돌파하면서 상승할 대는 주가 상승폭이 클 것으로 예상.
# ##### 주가가 장기간 횡보하며 급한 매물이 정리된 상태에서 들어온 신규 매수세력이 위력이 발휘할 것으로 보기 때문.
# ##### 반대로 주가가 장기 상승을 보인 후 고점에서 5일, 20일 이동평균선이 수렴한 상태로 주가가 이동평균선 아래로 떨어지면 하락폭이 클 것으로 보고 적극 매도.

# %% [markdown]
# ### 결론 - 골든크로스와 데드크로스를 활용한다.
# ##### 골든크로스 : 단기 이동평균선이 장기 이동평균선 아래에서 위로 상향 돌파하는 경우. 좋은 매수시점.
# ##### 데드크로스 : 단기 이동평균선이 장기 이동평균선을 위에서 아래로 하향 돌파하는 경우. 좋은 매도시점.
#
# ##### 이동평균선은 장기일 때는 그 질량이 크므로, 단기 이동평균선이 중장기 이동평균선과 같은 방향일 때는 추세가 강화되고, 다른 방향일 때는 보다 힘이 센 장기선의 방향으로 단기선이 끌려가게 된다.
# ##### 따라서 일봉에서 5일 이동평균선과 20일 이동평균선이 데드크로스를 그리더라도 120일, 200일 이동평균선이 상승추세를 이어간다면 이 데드크로스는 오히려 매수시점으로 보아야한다.
# ##### 또한 20일 이동평균선이 60일 이동평균선을 돌파하는 골든크로스가 나타난다고 하더라도 중장기 선인 120일, 200일 이동평균선이 하락을 이어간다면 매도시점으로 보아야 한다.

# %% [markdown]
# ## 함수에 코드를 넣을 경우. 해당 종목의 5일, 20일, 120일, 200일 이동평균선을 그리는 함수를 만들자

# %%
import urllib.parse ## url encoding

import FinanceDataReader as fdr
import datetime
from datetime import date, timedelta
import matplotlib.pyplot as plt

# %matplotlib inline
from matplotlib import font_manager, rc
import platform

# %%
def zeroFill(columnValue):

    columnValue = str(columnValue)

    outValue = columnValue.zfill(6) ## zerofill 6자리로 채워라

    return outValue

# %%
stock_code = '5490'

stock_code = zeroFill(stock_code)

# %%
stock_code
# Out:
# '005490'

# %%
df_krx = fdr.StockListing('KRX')

# %%
df_krx
# Out:
#       Symbol  Market     Name                    Sector  \
# 0     060310  KOSDAQ       3S             특수 목적용 기계 제조업
# 1     095570   KOSPI   AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI    AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ   APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ    AP시스템             특수 목적용 기계 제조업
# ...      ...     ...      ...                       ...
# 7054  000547   KOSPI  흥국화재2우B                       NaN
# 7055  000545   KOSPI    흥국화재우                       NaN
# 7056  003280   KOSPI     흥아해운                    해상 운송업
# 7057  037440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7058  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# 3                        인터넷 트래픽 솔루션  2001-12-04         12월
# 4                        디스플레이 제조 장비  2017-04-07         12월
# ...                              ...         ...         ...
# 7054                             NaN         NaT         NaN
# 7055                             NaN         NaT         NaN
# 7056                  외항화물운송업(케미컬탱커)  1976-06-29         12월
# 7057                       설계 및 감리용역  2000-02-03         12월
# 7058  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#             Representative                       HomePage Region
# 0       박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1                      박대현         http://www.ajnet.co.kr  서울특별시
# 2        채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3                      정기로   http://www.apsholdings.co.kr    경기도
# 4                      김영주     http://www.apsystems.co.kr    경기도
# ...                    ...                            ...    ...
# 7054                   NaN                            NaN    NaN
# 7055                   NaN                            NaN    NaN
# 7056                   이환구         http://www.heung-a.com  서울특별시
# 7057  정영균, 이목운, 허철호 (각자대표)          http://www.heerim.com  서울특별시
# 7058                   김주환          http://www.hims.co.kr  인천광역시
#
# [7059 rows x 10 columns]

# %%
MA_5 = 5 ## 단기추세선
MA_20 = 20 ## 단기추세선
MA_60 = 60 ## 단기추세선
MA_120 = 120 ## 장기추세선
MA_200 = 200 ## 장기추세선

# %%
end = date.today()  
start = date.today() - timedelta(365) # 1년 데이터.
targetStock = fdr.DataReader(stock_code, start, end)
targetName = df_krx.loc[df_krx.Symbol == stock_code].Name.item()

# %%
## values, value, item -- 선택 시 언제나 하나가 아닐 가능성이 있으니 0번째로 가져오는것이 item

# %%
print(stock_code)
print(targetName)
# Out:
# 005490
# POSCO

# %%
targetStock
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2020-06-09  201500  202000  193500  198500  662411 -0.019753
# 2020-06-10  195500  198000  194000  198000  357615 -0.002519
# 2020-06-11  195000  197000  190000  193500  637625 -0.022727
# 2020-06-12  185500  188000  184000  186500  473608 -0.036176
# 2020-06-15  182500  184500  175000  175000  467754 -0.061662
# ...            ...     ...     ...     ...     ...       ...
# 2021-06-03  349500  350500  345000  346500  607645 -0.018414
# 2021-06-04  346500  350500  345000  347000  475678  0.001443
# 2021-06-07  348500  349000  337500  339500  642429 -0.021614
# 2021-06-08  339000  342500  333000  341000  529180  0.004418
# 2021-06-09  340500  341000  333000  333500  535818 -0.021994
#
# [249 rows x 6 columns]

# %% [markdown]
# ## 종가를 기준으로 그래프를 그려보자

# %% [markdown]
# ## 롤링해보자

# %%
# STOCK["MA_5"]=STOCK["Close"].rolling(window=5).mean_periods=1.mean()
targetStock["MA_5"]=targetStock["Close"].rolling(window=MA_5).mean() # min_periods=1 5일치 종가를 가져와 rolling
targetStock["MA_20"]=targetStock["Close"].rolling(window=MA_20).mean()
targetStock["MA_60"]=targetStock["Close"].rolling(window=MA_60).mean()
targetStock["MA_120"]=targetStock["Close"].rolling(window=MA_120).mean()
targetStock["MA_200"]=targetStock["Close"].rolling(window=MA_200).mean()

targetStock
# Out:
#               Open    High     Low   Close  Volume    Change      MA_5  \
# Date
# 2020-06-09  201500  202000  193500  198500  662411 -0.019753       NaN
# 2020-06-10  195500  198000  194000  198000  357615 -0.002519       NaN
# 2020-06-11  195000  197000  190000  193500  637625 -0.022727       NaN
# 2020-06-12  185500  188000  184000  186500  473608 -0.036176       NaN
# 2020-06-15  182500  184500  175000  175000  467754 -0.061662  190300.0
# ...            ...     ...     ...     ...     ...       ...       ...
# 2021-06-03  349500  350500  345000  346500  607645 -0.018414  352300.0
# 2021-06-04  346500  350500  345000  347000  475678  0.001443  350300.0
# 2021-06-07  348500  349000  337500  339500  642429 -0.021614  347200.0
# 2021-06-08  339000  342500  333000  341000  529180  0.004418  345400.0
# 2021-06-09  340500  341000  333000  333500  535818 -0.021994  341500.0
#
#                MA_20          MA_60         MA_120    MA_200
# Date
# 2020-06-09       NaN            NaN            NaN       NaN
# 2020-06-10       NaN            NaN            NaN       NaN
# 2020-06-11       NaN            NaN            NaN       NaN
# 2020-06-12       NaN            NaN            NaN       NaN
# 2020-06-15       NaN            NaN            NaN       NaN
# ...              ...            ...            ...       ...
# 2021-06-03  371700.0  344650.000000  309554.166667  270470.0
# 2021-06-04  369275.0  345541.666667  310233.333333  271170.0
# 2021-06-07  366350.0  346150.000000  310787.500000  271825.0
# 2021-06-08  363050.0  346816.666667  311362.500000  272500.0
# 2021-06-09  359250.0  347241.666667  311812.500000  273115.0
#
# [249 rows x 11 columns]

# %%
plt.figure(figsize = (16,10))

#price (가격)
#plt.subplot(311)
plt.plot(targetStock.index, targetStock['Close'], label = 'Close')
plt.plot(targetStock.index, targetStock['MA_5'], label='MA 5day')
plt.plot(targetStock.index, targetStock['MA_20'], label='MA 20day')
plt.plot(targetStock.index, targetStock['MA_60'], label='MA 60day')
plt.plot(targetStock.index, targetStock['MA_120'], label='MA 120day')
plt.plot(targetStock.index, targetStock['MA_200'], label='MA 200day')
plt.title(targetName+" moving average")
plt.legend(loc='best') ## lengend = best 범례의 적당한 위치 지정.

# %% [markdown]
# ### 주가의 추세(하락인지 상승인지)를 파악.. 주가가 5일 이동평균선 위에 있으면 주가는 상승추세

# %%
targetStock
# Out:
#               Open    High     Low   Close  Volume    Change      MA_5  \
# Date
# 2020-06-09  201500  202000  193500  198500  662411 -0.019753       NaN
# 2020-06-10  195500  198000  194000  198000  357615 -0.002519       NaN
# 2020-06-11  195000  197000  190000  193500  637625 -0.022727       NaN
# 2020-06-12  185500  188000  184000  186500  473608 -0.036176       NaN
# 2020-06-15  182500  184500  175000  175000  467754 -0.061662  190300.0
# ...            ...     ...     ...     ...     ...       ...       ...
# 2021-06-03  349500  350500  345000  346500  607645 -0.018414  352300.0
# 2021-06-04  346500  350500  345000  347000  475678  0.001443  350300.0
# 2021-06-07  348500  349000  337500  339500  642429 -0.021614  347200.0
# 2021-06-08  339000  342500  333000  341000  529180  0.004418  345400.0
# 2021-06-09  340500  341000  333000  333500  535818 -0.021994  341500.0
#
#                MA_20          MA_60         MA_120    MA_200
# Date
# 2020-06-09       NaN            NaN            NaN       NaN
# 2020-06-10       NaN            NaN            NaN       NaN
# 2020-06-11       NaN            NaN            NaN       NaN
# 2020-06-12       NaN            NaN            NaN       NaN
# 2020-06-15       NaN            NaN            NaN       NaN
# ...              ...            ...            ...       ...
# 2021-06-03  371700.0  344650.000000  309554.166667  270470.0
# 2021-06-04  369275.0  345541.666667  310233.333333  271170.0
# 2021-06-07  366350.0  346150.000000  310787.500000  271825.0
# 2021-06-08  363050.0  346816.666667  311362.500000  272500.0
# 2021-06-09  359250.0  347241.666667  311812.500000  273115.0
#
# [249 rows x 11 columns]

# %%
## 평균선들의 추세를 계산.
MA_5_data = targetStock.MA_5
MA_20_data = targetStock.MA_20
MA_60_data = targetStock.MA_60
MA_120_data = targetStock.MA_120
MA_200_data = targetStock.MA_200

# %%
targetStock["MA_5_change"] = MA_5_data.pct_change() 
targetStock["MA_20_change"] = MA_20_data.pct_change() 
targetStock["MA_60_change"] = MA_60_data.pct_change() 
targetStock["MA_120_change"] = MA_120_data.pct_change() 
targetStock["MA_200_change"] = MA_200_data.pct_change()

# %%
targetStock["MA_5_change_per"] = targetStock.MA_5_change.pct_change()
targetStock["MA_20_change_per"] = targetStock.MA_20_change.pct_change()
targetStock["MA_60_change_per"] = targetStock.MA_60_change.pct_change()
targetStock["MA_120_change_per"] = targetStock.MA_120_change.pct_change()
targetStock["MA_200_change_per"] = targetStock.MA_200_change.pct_change()

# %%
targetStock
# Out:
#               Open    High     Low   Close  Volume    Change      MA_5  \
# Date
# 2020-06-09  201500  202000  193500  198500  662411 -0.019753       NaN
# 2020-06-10  195500  198000  194000  198000  357615 -0.002519       NaN
# 2020-06-11  195000  197000  190000  193500  637625 -0.022727       NaN
# 2020-06-12  185500  188000  184000  186500  473608 -0.036176       NaN
# 2020-06-15  182500  184500  175000  175000  467754 -0.061662  190300.0
# ...            ...     ...     ...     ...     ...       ...       ...
# 2021-06-03  349500  350500  345000  346500  607645 -0.018414  352300.0
# 2021-06-04  346500  350500  345000  347000  475678  0.001443  350300.0
# 2021-06-07  348500  349000  337500  339500  642429 -0.021614  347200.0
# 2021-06-08  339000  342500  333000  341000  529180  0.004418  345400.0
# 2021-06-09  340500  341000  333000  333500  535818 -0.021994  341500.0
#
#                MA_20          MA_60         MA_120  ...  MA_5_change  \
# Date                                                ...
# 2020-06-09       NaN            NaN            NaN  ...          NaN
# 2020-06-10       NaN            NaN            NaN  ...          NaN
# 2020-06-11       NaN            NaN            NaN  ...          NaN
# 2020-06-12       NaN            NaN            NaN  ...          NaN
# 2020-06-15       NaN            NaN            NaN  ...          NaN
# ...              ...            ...            ...  ...          ...
# 2021-06-03  371700.0  344650.000000  309554.166667  ...    -0.007606
# 2021-06-04  369275.0  345541.666667  310233.333333  ...    -0.005677
# 2021-06-07  366350.0  346150.000000  310787.500000  ...    -0.008850
# 2021-06-08  363050.0  346816.666667  311362.500000  ...    -0.005184
# 2021-06-09  359250.0  347241.666667  311812.500000  ...    -0.011291
#
#             MA_20_change  MA_60_change  MA_120_change  MA_200_change  \
# Date
# 2020-06-09           NaN           NaN            NaN            NaN
# 2020-06-10           NaN           NaN            NaN            NaN
# 2020-06-11           NaN           NaN            NaN            NaN
# 2020-06-12           NaN           NaN            NaN            NaN
# 2020-06-15           NaN           NaN            NaN            NaN
# ...                  ...           ...            ...            ...
# 2021-06-03     -0.004019      0.001429       0.002064       0.002743
# 2021-06-04     -0.006524      0.002587       0.002194       0.002588
# 2021-06-07     -0.007921      0.001761       0.001786       0.002415
# 2021-06-08     -0.009008      0.001926       0.001850       0.002483
# 2021-06-09     -0.010467      0.001225       0.001445       0.002257
#
#             MA_5_change_per  MA_20_change_per  MA_60_change_per  \
# Date
# 2020-06-09              NaN               NaN               NaN
# 2020-06-10              NaN               NaN               NaN
# 2020-06-11              NaN               NaN               NaN
# 2020-06-12              NaN               NaN               NaN
# 2020-06-15              NaN               NaN               NaN
# ...                     ...               ...               ...
# 2021-06-03        -4.367394          1.004019         -0.064921
# 2021-06-04        -0.253582          0.623191          0.810972
# 2021-06-07         0.558850          0.214106         -0.319518
# 2021-06-08        -0.414171          0.137213          0.093964
# 2021-06-09         1.177958          0.161982         -0.363725
#
#             MA_120_change_per  MA_200_change_per
# Date
# 2020-06-09                NaN                NaN
# 2020-06-10                NaN                NaN
# 2020-06-11                NaN                NaN
# 2020-06-12                NaN                NaN
# 2020-06-15                NaN                NaN
# ...                       ...                ...
# 2021-06-03          -0.127778          -0.054026
# 2021-06-04           0.063165          -0.056642
# 2021-06-07          -0.185835          -0.066701
# 2021-06-08           0.035744           0.028051
# 2021-06-09          -0.218837          -0.091146
#
# [249 rows x 21 columns]

# %% [markdown]
# ## 1. 적극적 매수, 매도 파악

# %% [markdown]
# ##### 1-1. 상승 전환 : 하락하던 주가가 5일 이동평균선을 상향 돌파하면 매수시점으로 본다. 주가가 5일, 20일 이동평균선을 차례로 돌파, 5일 이동평균선도 상승으로 돌아서면 적극 매수

# %%
## 상승추세 . 5일선 위에 있는 상태 
targetStock.loc[targetStock.Close > targetStock.MA_5]

## 20일선 돌파한 상태
targetStock.loc[targetStock.Close > targetStock.MA_20]

## 5일선과 20일선 둘다 돌파한 상태. 
targetStock.loc[ (targetStock.Close > targetStock.MA_5) & (targetStock.Close > targetStock.MA_20)  ]

## 저 상태에서 5일 평균선도 상승 추세라면?  적극 매수
buyPosition = targetStock.loc[ (targetStock.Close > targetStock.MA_5) & (targetStock.Close > targetStock.MA_20) & (targetStock.MA_5_change > 0)  ]

buyPosition
# Out:
#               Open    High     Low   Close  Volume    Change      MA_5  \
# Date
# 2020-07-07  185500  189000  184000  185000  358072  0.010929  181800.0
# 2020-07-08  185500  191500  184000  190500  537845  0.029730  184200.0
# 2020-07-09  192000  192000  187000  188500  375630 -0.010499  185700.0
# 2020-07-13  184000  188000  182000  187000  261632  0.027473  186600.0
# 2020-07-17  189000  191500  186000  186500  222271  0.000000  186200.0
# ...            ...     ...     ...     ...     ...       ...       ...
# 2021-04-29  376000  387000  372500  373000  629282  0.001342  368200.0
# 2021-05-06  380500  396000  380500  395500  716999  0.050465  375400.0
# 2021-05-07  396500  399000  388000  398000  422259  0.006321  380400.0
# 2021-05-10  400000  413500  399000  407000  643587  0.022613  389000.0
# 2021-05-11  406000  412000  396000  409500  710220  0.006143  397300.0
#
#                MA_20          MA_60         MA_120  ...  MA_5_change  \
# Date                                                ...
# 2020-07-07  184000.0            NaN            NaN  ...     0.012249
# 2020-07-08  183625.0            NaN            NaN  ...     0.013201
# 2020-07-09  183375.0            NaN            NaN  ...     0.008143
# 2020-07-13  183750.0            NaN            NaN  ...     0.004306
# 2020-07-17  183375.0            NaN            NaN  ...     0.004857
# ...              ...            ...            ...  ...          ...
# 2021-04-29  345450.0  309491.666667  284683.333333  ...     0.010983
# 2021-05-06  355125.0  317008.333333  289500.000000  ...     0.012406
# 2021-05-07  358450.0  319166.666667  290829.166667  ...     0.013319
# 2021-05-10  362400.0  321450.000000  292250.000000  ...     0.022608
# 2021-05-11  366400.0  323758.333333  293695.833333  ...     0.021337
#
#             MA_20_change  MA_60_change  MA_120_change  MA_200_change  \
# Date
# 2020-07-07     -0.003655           NaN            NaN            NaN
# 2020-07-08     -0.002038           NaN            NaN            NaN
# 2020-07-09     -0.001361           NaN            NaN            NaN
# 2020-07-13      0.003276           NaN            NaN            NaN
# 2020-07-17     -0.001089           NaN            NaN            NaN
# ...                  ...           ...            ...            ...
# 2021-04-29      0.007951      0.006504       0.004528       0.003664
# 2021-05-06      0.009451      0.007015       0.004583       0.004175
# 2021-05-07      0.009363      0.006808       0.004591       0.004168
# 2021-05-10      0.011020      0.007154       0.004885       0.004327
# 2021-05-11      0.011038      0.007181       0.004947       0.004357
#
#             MA_5_change_per  MA_20_change_per  MA_60_change_per  \
# Date
# 2020-07-07         0.454417               NaN               NaN
# 2020-07-08         0.077708         -0.442406               NaN
# 2020-07-09        -0.383143         -0.331972               NaN
# 2020-07-13         6.995694         -3.669943               NaN
# 2021-01-27           0.125791                NaN
# 2021-01-28          -0.123328                NaN
# 2021-01-29          -0.113944                NaN
# 2021-02-01           0.143487                NaN
# 2021-03-19          -0.088494                NaN
# 2021-05-17          -0.077875          -0.063573
# 2021-05-20          -0.182432          -0.120722
# 2021-05-21          -0.052583          -0.068097
# 2021-05-24          -0.046342          -0.028240
# 2021-05-25           0.042068           0.029458
# 2021-05-26          -0.054954          -0.024947
# 2021-05-31          -0.061151          -0.015280
# 2021-06-01          -0.064575          -0.077312
# 2021-06-03          -0.127778          -0.054026
# 2021-06-04           0.063165          -0.056642
# 2021-06-07          -0.185835          -0.066701
# 2021-06-08           0.035744           0.028051
# 2021-06-09          -0.218837          -0.091146
#
# [41 rows x 21 columns]

# %% [markdown]
# ## 2. 이외의 조건에 따른 매수, 매도 파악.

# %% [markdown]
# ##### 골든크로스 : 단기 이동평균선이 장기 이동평균선 아래에서 위로 상향 돌파하는 경우. 좋은 매수시점.
# ##### 데드크로스 : 단기 이동평균선이 장기 이동평균선을 위에서 아래로 하향 돌파하는 경우. 좋은 매도시점.
#
# ##### 이동평균선은 장기일 때는 그 질량이 크므로, 단기 이동평균선이 중장기 이동평균선과 같은 방향일 때는 추세가 강화되고, 다른 방향일 때는 보다 힘이 센 장기선의 방향으로 단기선이 끌려가게 된다.
# ##### 따라서 일봉에서 5일 이동평균선과 20일 이동평균선이 데드크로스를 그리더라도 120일, 200일 이동평균선이 상승추세를 이어간다면 이 데드크로스는 오히려 매수시점으로 보아야한다.
# ##### 또한 20일 이동평균선이 60일 이동평균선을 돌파하는 골든크로스가 나타난다고 하더라도 중장기 선인 120일, 200일 이동평균선이 하락을 이어간다면 매도시점으로 보아야 한다.

# %%
targetStock
# Out:
#               Open    High     Low   Close  Volume    Change      MA_5  \
# Date
# 2020-06-09  201500  202000  193500  198500  662411 -0.019753       NaN
# 2020-06-10  195500  198000  194000  198000  357615 -0.002519       NaN
# 2020-06-11  195000  197000  190000  193500  637625 -0.022727       NaN
# 2020-06-12  185500  188000  184000  186500  473608 -0.036176       NaN
# 2020-06-15  182500  184500  175000  175000  467754 -0.061662  190300.0
# ...            ...     ...     ...     ...     ...       ...       ...
# 2021-06-03  349500  350500  345000  346500  607645 -0.018414  352300.0
# 2021-06-04  346500  350500  345000  347000  475678  0.001443  350300.0
# 2021-06-07  348500  349000  337500  339500  642429 -0.021614  347200.0
# 2021-06-08  339000  342500  333000  341000  529180  0.004418  345400.0
# 2021-06-09  340500  341000  333000  333500  535818 -0.021994  341500.0
#
#                MA_20          MA_60         MA_120  ...  MA_5_change  \
# Date                                                ...
# 2020-06-09       NaN            NaN            NaN  ...          NaN
# 2020-06-10       NaN            NaN            NaN  ...          NaN
# 2020-06-11       NaN            NaN            NaN  ...          NaN
# 2020-06-12       NaN            NaN            NaN  ...          NaN
# 2020-06-15       NaN            NaN            NaN  ...          NaN
# ...              ...            ...            ...  ...          ...
# 2021-06-03  371700.0  344650.000000  309554.166667  ...    -0.007606
# 2021-06-04  369275.0  345541.666667  310233.333333  ...    -0.005677
# 2021-06-07  366350.0  346150.000000  310787.500000  ...    -0.008850
# 2021-06-08  363050.0  346816.666667  311362.500000  ...    -0.005184
# 2021-06-09  359250.0  347241.666667  311812.500000  ...    -0.011291
#
#             MA_20_change  MA_60_change  MA_120_change  MA_200_change  \
# Date
# 2020-06-09           NaN           NaN            NaN            NaN
# 2020-06-10           NaN           NaN            NaN            NaN
# 2020-06-11           NaN           NaN            NaN            NaN
# 2020-06-12           NaN           NaN            NaN            NaN
# 2020-06-15           NaN           NaN            NaN            NaN
# ...                  ...           ...            ...            ...
# 2021-06-03     -0.004019      0.001429       0.002064       0.002743
# 2021-06-04     -0.006524      0.002587       0.002194       0.002588
# 2021-06-07     -0.007921      0.001761       0.001786       0.002415
# 2021-06-08     -0.009008      0.001926       0.001850       0.002483
# 2021-06-09     -0.010467      0.001225       0.001445       0.002257
#
#             MA_5_change_per  MA_20_change_per  MA_60_change_per  \
# Date
# 2020-06-09              NaN               NaN               NaN
# 2020-06-10              NaN               NaN               NaN
# 2020-06-11              NaN               NaN               NaN
# 2020-06-12              NaN               NaN               NaN
# 2020-06-15              NaN               NaN               NaN
# ...                     ...               ...               ...
# 2021-06-03        -4.367394          1.004019         -0.064921
# 2021-06-04        -0.253582          0.623191          0.810972
# 2021-06-07         0.558850          0.214106         -0.319518
# 2021-06-08        -0.414171          0.137213          0.093964
# 2021-06-09         1.177958          0.161982         -0.363725
#
#             MA_120_change_per  MA_200_change_per
# Date
# 2020-06-09                NaN                NaN
# 2020-06-10                NaN                NaN
# 2020-06-11                NaN                NaN
# 2020-06-12                NaN                NaN
# 2020-06-15                NaN                NaN
# ...                       ...                ...
# 2021-06-03          -0.127778          -0.054026
# 2021-06-04           0.063165          -0.056642
# 2021-06-07          -0.185835          -0.066701
# 2021-06-08           0.035744           0.028051
# 2021-06-09          -0.218837          -0.091146
#
# [249 rows x 21 columns]

# %% [markdown]
# #### 2-1. 20일 이동평균선이 60일 이동평균선을 돌파하는 골든크로스가 나타난 경우. 이 상태에서 120일선과 200일선이 하락을 이어간다면 매도시점이다.

# %%
gcButSell = targetStock.loc[ (targetStock.MA_20 > targetStock.MA_60) & (targetStock.MA_120_change_per < 0) & (targetStock.MA_200_change_per < 0) ]

# %%
gcButSell
# Out:
#               Open    High     Low   Close  Volume    Change      MA_5  \
# Date
# 2021-04-09  334500  336000  326500  328000  256857 -0.010558  330300.0
# 2021-04-21  350000  355000  346000  351000  434931 -0.012658  350000.0
# 2021-04-28  380000  381500  369500  372500  545333 -0.013245  364200.0
# 2021-04-30  373500  374000  360000  364000  499655 -0.024129  369900.0
# 2021-05-12  407500  409000  390500  399000  631639 -0.025641  401800.0
# 2021-05-13  384500  399000  380000  383500  756875 -0.038847  399400.0
# 2021-05-14  381000  386500  374500  380000  567800 -0.009126  395800.0
# 2021-05-17  380000  385000  363500  367000  661551 -0.034211  387800.0
# 2021-05-20  373500  374000  363000  365000  743678 -0.053178  376200.0
# 2021-05-21  365000  368000  354000  360000  623771 -0.013699  371500.0
# 2021-05-24  357500  364000  354000  355500  594767 -0.012500  366600.0
# 2021-04-21        -0.568598          0.051989          0.041460
# 2021-04-28        -0.034675         -0.053173         -0.010853
# 2021-04-30        -0.579617         -0.171723         -0.163772
# 2021-05-12        -0.469158         -0.109825         -0.060895
# 2021-05-13        -1.527360         -0.381081         -0.150765
# 2021-05-14         0.509014         -0.249011         -0.027889
# 2021-05-17         1.242434         -0.311966         -0.073650
# 2021-05-20         0.434421         -0.699674         -0.209768
# 2021-05-21        -0.296330         -0.053825         -0.174108
# 2021-05-24         0.055743         -0.722553          0.008384
# 2021-05-26         3.075567         -6.398214         -0.103319
# 2021-05-28        -0.398317         -0.112226         -0.229499
# 2021-05-31        -0.833052          0.163687         -0.209136
# 2021-06-01        15.004497         -0.220354         -0.229986
# 2021-06-03        -4.367394          1.004019         -0.064921
# 2021-06-07         0.558850          0.214106         -0.319518
# 2021-06-09         1.177958          0.161982         -0.363725
#
#             MA_120_change_per  MA_200_change_per
# Date
# 2021-04-09          -0.064902          -0.023742
# 2021-04-21          -0.051227          -0.020300
# 2021-04-28          -0.063313          -0.039769
# 2021-04-30          -0.114400          -0.041867
# 2021-05-12          -0.082350          -0.055684
# 2021-05-13          -0.097846          -0.095918
# 2021-05-14          -0.028118          -0.053002
# 2021-05-17          -0.077875          -0.063573
# 2021-05-20          -0.182432          -0.120722
# 2021-05-21          -0.052583          -0.068097
# 2021-05-24          -0.046342          -0.028240
# 2021-05-26          -0.054954          -0.024947
# 2021-05-28          -0.118120          -0.032819
# 2021-05-31          -0.061151          -0.015280
# 2021-06-01          -0.064575          -0.077312
# 2021-06-03          -0.127778          -0.054026
# 2021-06-07          -0.185835          -0.066701
# 2021-06-09          -0.218837          -0.091146
#
# [18 rows x 21 columns]

# %% [markdown]
# #### 2-2. 일봉에서 5일 이동평균선과 20일 이동평균선이 데드크로스를 그리더라도 120일, 200일 이동평균선이 상승추세를 이어간다면 이 데드크로스는 오히려 매수시점으로 보아야한다.

# %%
dcButBuy = targetStock.loc[ (targetStock.MA_5 < targetStock.MA_20) & (targetStock.MA_120_change_per > 0) & (targetStock.MA_200_change_per > 0) ]

# %%
dcButBuy
# Out:
#               Open    High     Low   Close  Volume    Change      MA_5  \
# Date
# 2021-05-25  358000  361000  353500  358000  392354  0.007032  364800.0
# 2021-05-27  352000  360000  349000  360000  763321  0.031519  356500.0
# 2021-06-08  339000  342500  333000  341000  529180  0.004418  345400.0
#
#                MA_20          MA_60    MA_120  ...  MA_5_change  MA_20_change  \
# Date                                           ...
# 2021-05-25  377875.0  338933.333333  303600.0  ...    -0.004910      0.000331
# 2021-05-27  376325.0  341308.333333  305562.5  ...    -0.002797     -0.002320
# 2021-06-08  363050.0  346816.666667  311362.5  ...    -0.005184     -0.009008
#
#             MA_60_change  MA_120_change  MA_200_change  MA_5_change_per  \
# Date
# 2021-05-25      0.003702       0.003180       0.003009        -0.627743
# 2021-05-27      0.003676       0.003448       0.003161        -0.860216
# 2021-06-08      0.001926       0.001850       0.002483        -0.414171
#
#             MA_20_change_per  MA_60_change_per  MA_120_change_per  \
# Date
# 2021-05-25         -0.000331         -0.083456           0.042068
# 2021-05-27          0.298616          0.107435           0.147237
# 2021-06-08          0.137213          0.093964           0.035744
#
#             MA_200_change_per
# Date
# 2021-05-25           0.029458
# 2021-05-27           0.077225
# 2021-06-08           0.028051
#
# [3 rows x 21 columns]

# %% [markdown]
# ## 3. 적절한 종목인지 판단하는 함수를 만들어보자

# %% [markdown]
# ### 3-1. 부실위험이 있거나 매출액, 영업이익이 감소하는 추세의 종목
# ### 3-2. 일일 평균거래량이 3만주 이내로 적은 종목
# ### 3-3. 단기에 지나치게 급등한 종목
# ### 3-4. 동일업종 비교 per

# %%
stock_code = '5490'

stock_code = zeroFill(stock_code)

# %%
stock_code
# Out:
# '005490'

# %%
#
from bs4 import BeautifulSoup 
import requests 
import pandas as pd

url = 'https://finance.naver.com/item/main.nhn?code='+stock_code
table_df_list = pd.read_html(url, encoding='euc-kr')    
table_df = table_df_list[3]
table_df
# Out:
#        주요재무정보   최근 연간 실적                                    최근 분기 실적  \
#        주요재무정보    2018.12    2019.12    2020.12 2021.12(E)    2020.03
#        주요재무정보     IFRS연결     IFRS연결     IFRS연결     IFRS연결     IFRS연결
# 0         매출액  649778.00  643668.00  577928.00  657534.00  145458.00
# 1        영업이익   55426.00   38689.00   24030.00   61810.00    7053.00
# 2       당기순이익   18921.00   19826.00   17882.00   42208.00    4347.00
# 3       영업이익률       8.53       6.01       4.16       9.40       4.85
# 4        순이익률       2.91       3.08       3.09       6.42       2.99
# 5   ROE(지배주주)       3.88       4.18       3.61       8.52       3.38
# 6        부채비율      67.34      65.41      65.89        NaN      73.49
# 7        당좌비율     116.79     146.09     158.68        NaN     147.59
# 8         유보율    9458.18    9630.20    9830.37        NaN    9634.92
# 9      EPS(원)   19391.00   21048.00   18376.00   44780.00    4535.00
# 10     PER(배)      12.53      11.24      14.80       7.62       9.43
# 11     BPS(원)  542133.00  555096.00  583188.00  625449.00  552135.00
# 12     PBR(배)       0.45       0.43       0.47       0.55       0.29
# 13   주당배당금(원)   10000.00   10000.00    8000.00   10467.00        NaN
# 14   시가배당률(%)       4.12       4.23       2.94        NaN        NaN
# 15    배당성향(%)      47.32      43.66      38.72        NaN        NaN
#
#
#       2020.06    2020.09    2020.12    2021.03 2021.06(E)
#        IFRS연결     IFRS연결     IFRS연결     IFRS연결     IFRS연결
# 0   137216.00  142612.00  152642.00  160687.00  166384.00
# 1     1677.00    6667.00    8634.00   15524.00   16556.00
# 2     1049.00    5140.00    7346.00   11388.00   11636.00
# 3        1.22       4.67       5.66       9.66       9.95
# 4        0.76       3.60       4.81       7.09       6.99
# 5        2.07       2.13       3.61       4.99        NaN
# 6       72.53      71.77      65.89      68.29        NaN
# 7      152.79     158.52     158.68     158.88        NaN
# 8     9616.76    9699.89    9830.37    9979.51        NaN
# 9      462.00    5339.00    8040.00   11753.00   12170.00
# 10      16.54      17.95      14.80      12.50      28.02
# 11  555827.00  566971.00  583188.00  598503.00        NaN
# 12       0.31       0.35       0.47       0.53        NaN
# 13        NaN        NaN        NaN        NaN        NaN
# 14        NaN        NaN        NaN        NaN        NaN
# 15        NaN        NaN        NaN        NaN        NaN

# %% [markdown]
# ### 3-1. 매출액이 감소하는 추세인지 확인해보자

# %%
earningInfo = table_df_list[3]

earningInfo

# %%
recentEarningRate = pd.DataFrame(earningInfo.values[4][1:5])

# %%
recentEarningRate
# Out:
#       0
# 0  2.91
# 1  3.08
# 2  3.09
# 3  6.42

# %%
recentEarningRate["compareBeforeAYear"] = recentEarningRate.pct_change()

# %%
recentEarningRate
# Out:
#       0  compareBeforeAYear
# 0  2.91                 NaN
# 1  3.08            0.058419
# 2  3.09            0.003247
# 3  6.42            1.077670

# %%
recentEarningRate.loc[recentEarningRate.compareBeforeAYear < 0 ]
# Out:
# Empty DataFrame
# Columns: [0, compareBeforeAYear]
# Index: []

# %% [markdown]
# ### 3-2. 부채비율이 200이상인 부실기업인지

# %%
debtRatio = earningInfo.values[6]

AvgDebtRatio = debtRatio[5:9].mean()

AvgDebtRatio >= 200

# %% [markdown]
# ### 3-3. 일일 평균거래량이 3만주 이내로 적은 종목

# %%
targetStock.Volume.mean() < 30000
# Out:
# False

# %% [markdown]
# ### 3-4. 상대강도과열종목인지 - 함수로 묶자

# %%
overHeatUrl = 'https://finance.naver.com/sise/item_overheating_2.nhn'
# overHeatList = pd.read_html(overHeatUrl, encoding='euc-kr')  

resp = requests.get(url=overHeatUrl) ## response 200 = 정상, 확인완료
resp.encoding = "euc-kr" ## 인코딩
html = resp.text
htmlObj = BeautifulSoup(html, "html.parser") ## beautifulSoup 사용

## 목표 테이블 추출.
targetList = htmlObj.findAll("a","tltle")

targetList[0].text

overHeatNameList = []

for i in range(0, len(targetList)):
    overHeatNameList.append(targetList[i].text)

# %%
overHeatNameList
# Out:
# ['쎄미시스코',
#  '쌍방울',
#  '두산2우B',
#  '하림',
#  'KBI메탈',
#  '티웨이항공',
#  '신성통상',
#  '엔케이물산',
#  '셀리드',
#  '현대에버다임',
#  '진흥기업',
#  '세중',
#  '휴젤',
#  '조이시티',
#  '아스트',
#  '자연과환경',
#  '한국공항',
#  '양지사',
#  '트루윈',
#  '영화테크',
#  '금호타이어',
#  'DRB동일',
#  '화신',
#  'NE능률',
#  '아이엠텍',
#  '큐로컴',
#  '하이즈항공',
#  '이녹스첨단소재',
#  '디지탈옵틱',
#  '코리아에스이',
#  'F&F',
#  '웹스',
#  '성우하이텍',
#  '서남',
#  '블루베리 NFT',
#  '파인디지털',
#  '켄코아에어로스페이스',
#  '시큐브',
#  '디지아이',
#  '이리츠코크렙',
#  '한국가스공사',
#  'TIGER 원유선물Enhanced(H)',
#  'KBSTAR 미국S&P원유생산기업(합성 H)',
#  '리더스 기술투자',
#  '네오크레마',
#  '이지스밸류리츠',
#  '빛샘전자',
#  '맵스리얼티1',
#  '덕산네오룩스',
#  'TIGER 방송통신',
#  'ESR켄달스퀘어리츠',
#  '파워로직스',
#  '삼성 Cushing 에너지인프라 MLP ETN',
#  '모나미',
#  '만도',
#  '이니텍',
#  '퍼스텍',
#  '미래에셋 글로벌 리츠 ETN(H)',
#  '이상네트웍스',
#  'TIGER 미국MSCI리츠(합성 H)',
#  '비나텍',
#  '대성홀딩스',
#  '효성중공업',
#  'TIGER KIS부동산인프라채권TR',
#  'KODEX 미국러셀2000(H)',
#  'KODEX 다우존스미국리츠(H)',
#  '라온시큐어',
#  '미래에셋 미국 항공우주 ETN(H)',
#  '한익스프레스',
#  '덴티움',
#  '하이골드3호',
#  'KBSTAR 글로벌데이터센터리츠나스닥(합성)',
#  'KINDEX 러시아MSCI(합성)',
#  '효성ITX',
#  '아진산업',
#  '서부T&D',
#  '마니커에프앤지',
#  'KINDEX 미국다우존스리츠(합성 H)',
#  'KODEX 미국채울트라30년선물(H)',
#  '선광',
#  '유비케어',
#  '누리플렉스',
#  '옴니시스템',
#  '현대로템',
#  'KOSEF 인도Nifty50(합성)',
#  'KB 인버스 2X 항셍테크 선물 ETN',
#  '브릿지바이오테라퓨틱스',
#  '포스코 ICT',
#  '삼화왕관',
#  '국영지앤엠',
#  'LS전선아시아',
#  '유니온머티리얼',
#  '삼성화재',
#  '대교',
#  '우리기술',
#  'NH프라임리츠',
#  'HANARO 글로벌럭셔리S&P(합성)',
#  'TJ미디어',
#  'TIGER 유로스탁스50(합성 H)',
#  'GS글로벌',
#  '넥센우',
#  '코센',
#  '유양디앤유',
#  '아시아나항공',
#  '인성정보',
#  '골드앤에스',
#  '에이아이비트',
#  '스포츠서울',
#  '솔고바이오',
#  '크로바하이텍',
#  '아래스',
#  '이에스에이',
#  '아이톡시',
#  '비츠로시스',
#  '씨앤티85',
#  '제이웨이',
#  '슈펙스비앤피',
#  '레드로버',
#  '바른전자',
#  '제낙스',
#  '한프',
#  '이엠앤아이',
#  '이엠네트웍스',
#  '하이소닉',
#  '지유온',
#  '지스마트글로벌',
#  '인터로조',
#  '이큐셀',
#  '미래테크놀로지',
#  '경남제약헬스케어',
#  'KODEX 단기변동금리부채권액티브',
#  'TIGER 200커버드콜ATM',
#  '마이티 200커버드콜ATM레버리지',
#  'SMART KIS단기통안채',
#  '신한 코스피 콘도르 6/10% ETN',
#  '삼성 코스피 풋매도 ETN',
#  '삼성 코스피 풋매도 4% OTM ETN',
#  'QV iSelect 글로벌 EMP ETN(H)',
#  'TRUE 코스피 커버드콜 ETN B',
#  'TRUE 인버스 유로선물 ETN B',
#  'TRUE 유로스탁스50 양매도 5% OTM ETN(H)',
#  'TRUE S&P500 양매도 4% OTM ETN(H)',
#  '미래에셋 미국 리츠 ETN(H)',
#  '하나 코스피 변동성추세 추종 양매도 ETN',
#  'SNT모티브',
#  '부산가스',
#  'KBSTAR Fn수소경제테마',
#  'SGA솔루션즈',
#  '이노션',
#  '서전기전',
#  'KODEX K-미래차액티브',
#  '상상인증권',
#  'SK가스',
#  '마이다스 200커버드콜5%OTM',
#  '파인테크닉스',
#  'TIGER 200 경기소비재',
#  'KODEX 자동차',
#  '원익피앤이',
#  '고려신용정보',
#  'KBSTAR 200경기소비재',
#  '상보',
#  '리드코프',
#  'KEC',
#  '삼성중공업',
#  '기아',
#  'HDC현대산업개발',
#  '빅솔론',
#  '토니모리',
#  '세보엠이씨',
#  '피엔에이치테크',
#  '광명전기',
#  '한전산업',
#  '한국전자인증']

# %%
for i in range(0, len(overHeatNameList)):
    if targetName == overHeatNameList[i]:
        print("과열종목입니다")

# %% [markdown]
# ### 3-5. 동일업종 비교 per

# %%
## 해당연도 분기별 per평균
targetStockAvgPER = float(earningInfo.values[10][5:-1].mean())

sameBusniessPER = table_df_list[9]

targetBusniessPER = sameBusniessPER[1].values[0]

targetBusniessPER = float(targetBusniessPER.split("배")[0])

targetStockAvgPER <= targetBusniessPER

# %% [markdown]
# ### 3번 함수화

# %%
from bs4 import BeautifulSoup 
import requests 
import pandas as pd

stock_code = '5490'
stock_code = zeroFill(stock_code)

end = date.today()  
start = date.today() - timedelta(365) # 1년 데이터.
targetStock = fdr.DataReader(stock_code, start, end)
targetName = df_krx.loc[df_krx.Symbol == stock_code].Name.item()

url = 'https://finance.naver.com/item/main.nhn?code='+stock_code
table_df_list = pd.read_html(url, encoding='euc-kr')    
earningInfo = table_df_list[3]
earningArray = earningInfo.values[4][1:5]

# 3-1. 매출액이 감소하는 추세인지 확인해보자. 10퍼센트 이상 올랐으면 true,  아니면 false
recentEarningRate = pd.DataFrame(earningArray)
recentEarningRate["compareBeforeAYear"] = recentEarningRate.pct_change()
growthRate = recentEarningRate.compareBeforeAYear[3]

if growthRate >= 0.1:
    print("True")

# 3-2. 부채비율이 200이상인 부실기업인지 확인해보자.
debtRatio = earningInfo.values[6]
AvgDebtRatio = debtRatio[5:9].mean()
if AvgDebtRatio >= 200:
    print("부실기업이다") 
    

# 3-3. 일일 평균거래량이 3만주 이내로 적은 종목
if targetStock.Volume.mean() < 30000:
    print("거래량이 작은 종목이다")
    
    
# 3-4 상대강도과열종목인지()
if overHeatStock(stock_code) == True:
    print("과열종목이다")


# 3-5. 동일업종 PER보다 해당 종목의 PER이 낮은지 확인해본다.

targetStockAvgPER = float(earningInfo.values[10][5:-1].mean())

sameBusniessPER = table_df_list[9]

targetBusniessPER = sameBusniessPER[1].values[0]

targetBusniessPER = float(targetBusniessPER.split("배")[0])

if targetStockAvgPER <= targetBusniessPER:
    print("저평가된 주식입니다")
# Out:
# True
# 22

# %%
### 과열종목 판단 함수. true 일 경우 최근 상대강도과열종목.
def overHeatStock(stock_code):
    from bs4 import BeautifulSoup 
    import requests 
    import datetime
    from datetime import date, timedelta
    import FinanceDataReader as fdr
    
    
    stock_code =  str(stock_code).zfill(6)
    end = date.today()  
    start = date.today() - timedelta(365) # 1년 데이터.
    targetStock = fdr.DataReader(stock_code, start, end)
    df_krx = fdr.StockListing('KRX')
    targetName = df_krx.loc[df_krx.Symbol == stock_code].Name.item() ## 해당 종목 이름 가져오기
    
    overHeatUrl = 'https://finance.naver.com/sise/item_overheating_2.nhn'
    resp = requests.get(url=overHeatUrl) ## response 200 = 정상, 확인완료
    resp.encoding = "euc-kr" ## 인코딩
    html = resp.text
    htmlObj = BeautifulSoup(html, "html.parser") ## beautifulSoup 사용

    ## 목표 테이블 추출. 상대강도과열종목의 이름 List
    targetList = htmlObj.findAll("a","tltle")

    targetList[0].text

    overHeatNameList = []

    for i in range(0, len(targetList)):
        overHeatNameList.append(targetList[i].text)


    for i in range(0, len(overHeatNameList)):
        if targetName == overHeatNameList[i]:
            return True
        else: return False

# %%
overHeatStock(5490)
# Out:
# False
